# %% [markdown]
# ### Step 1. 필요한 라이브러리 임포트

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. [데이터](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv) 확인
#
# - order_id 주문번호
# - quantity 주문 개수
# - item_name 주문한 상품명
# - choice_description 선택사항
# - item_price 가격

# %% [markdown]
# ### Step 3. 데이터 불러오기
#
#
# **read_csv를 통해 데이터를 올바른 형태로 불러온 뒤 chipo에 저장해주세요**

# %%
# !ls
# !cd sample_data
# Out:
# sample_data

# %%
cd sample_data
# Out:
# /content/sample_data

# %%
# !ls
# Out:
# anscombe.json		      mnist_test.csv
# california_housing_test.csv   mnist_train_small.csv
# california_housing_train.csv  README.md

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-88ea8457-c0d9-4ab2-b18b-187fb3189a7c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-88ea8457-c0d9-4ab2-b18b-187fb3189a7c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving stock_data.csv to stock_data.csv

# %%
chipo = pd.read_csv('stock_data.csv', encoding='cp949')

# %%
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv'
    
# chipo = pd.read_csv('chipotle.tsv', sep = '\t')
chipo = pd.read_csv(url, sep = '\t')

# %% [markdown]
# ### Step 4. 초반 10행 조회

# %%
chipo.head(10)
# Out:
#    order_id  ...  item_price
# 0         1  ...      $2.39
# 1         1  ...      $3.39
# 2         1  ...      $3.39
# 3         1  ...      $2.39
# 4         2  ...     $16.98
# 5         3  ...     $10.98
# 6         3  ...      $1.69
# 7         4  ...     $11.75
# 8         4  ...      $9.25
# 9         5  ...      $9.25
#
# [10 rows x 5 columns]

# %%
len(chipo.groupby('item_name'))
# Out:
# 50

# %%
chipo[chipo['choice_description'].isna() == False].groupby('choice_description').sum().sort_values('quantity', ascending=False).head(1).index[0]
# Out:
# '[Diet Coke]'

# %%
chipo.groupby('item_name').sum().sort_values('quantity', ascending=False).head(1).iloc[0,1]
# Out:
# 761

# %% [markdown]
# ### Step 5. 데이터셋은 몇 개의 행으로 이루어져 있나요? (최소 2가지 이상 풀이법으로 풀어주세요)
#
# 4622

# %%
alist = list(chipo.columns)
alist
# Out:
# ['order_id', 'quantity', 'item_name', 'choice_description', 'item_price']

# %%
# Solution 1

chipo.shape[0]  # entries <= 4622 observations
# Out:
# 4622

# %%
# Solution 2

chipo.info() # entries <= 4622 observations
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %% [markdown]
# ### Step 6. 데이터셋은 몇 개의 열로 이루어져 있나요?
#
# 5

# %%
chipo.shape[1]
# Out:
# 5

# %% [markdown]
# ### Step 7. 열(column)의 이름들을 모두 조회해주세요
#
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
chipo.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %% [markdown]
# ### Step 8. 데이터셋의 인덱스를 조회해주세요
#
# RangeIndex(start=0, stop=4622, step=1)

# %%
chipo[chipo.index == 1000]
# Out:
#       order_id  ...  item_price
# 1000       411  ...      $8.49
#
# [1 rows x 5 columns]

# %%
chipo.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %% [markdown]
# ### Step 9. 가장 많은 개수가 주문된 item_name은 무엇인가요?
#
# Chicken Bowl

# %%
c = chipo.groupby('item_name')
c = c.sum()
c = c.sort_values(['quantity'], ascending=False)
c.head(1)
# Out:
#               order_id  quantity
# item_name
# Chicken Bowl    713926       761

# %% [markdown]
# ### Step 10. 가장 많이 주문된 item은 몇 개 주문되었나요?
#
# 761

# %%
c = chipo.groupby('item_name')
c = c.sum()
c = c.sort_values(['quantity'], ascending=False)
c.head(1)
# Out:
#               order_id  quantity
# item_name
# Chicken Bowl    713926       761

# %% [markdown]
# ### Step 11. choice_description에서 가장 많이 주문된건 어떤 항목인가요?
#
# Diet Coke 159

# %%
c = chipo.groupby('choice_description').sum()
c = c.sort_values(['quantity'], ascending=False)
c.head(1)
# Diet Coke 159
# Out:
#                     order_id  quantity
# choice_description
# [Diet Coke]           123455       159

# %% [markdown]
# ### Step 12. 총 몇 개의 item이 주문되었나요? (quantity의 총 합을 구해주세요)
#
# 4972

# %%
total_items_orders = chipo.quantity.sum()
total_items_orders
# Out:
# 4972

# %% [markdown]
# ### Step 13. item price를 float로 변경해주세요

# %%
chipo
# Out:
#       order_id  ...  item_price
# 0            1  ...      $2.39
# 1            1  ...      $3.39
# 2            1  ...      $3.39
# 3            1  ...      $2.39
# 4            2  ...     $16.98
# ...        ...  ...         ...
# 4617      1833  ...     $11.75
# 4618      1833  ...     $11.75
# 4619      1834  ...     $11.25
# 4620      1834  ...      $8.75
# 4621      1834  ...      $8.75
#
# [4622 rows x 5 columns]

# %% [markdown]
# #### Step 13.a. item_price의 데이터타입을 조회해주세요
#
# dtype('O')

# %%
chipo.item_price.dtype
# Out:
# dtype('O')

# %%
chipo.item_price.dtype
# Out:
# dtype('O')

# %% [markdown]
# #### Step 13.b. item_type에서 $기호를 제거하고 숫자 부분을 float으로 형변환 후 기존 dataframe에 저장해주세요
#
# 람다함수를 활용하면 편리합니다

# %%
def setfloat(x):
  return float(x[1:-1])

# %%
chipo['item_price'] = chipo['item_price'].agg(setfloat)

# %%
chipo.head()
# Out:
#    order_id  ...  item_price
# 0         1  ...        2.39
# 1         1  ...        3.39
# 2         1  ...        3.39
# 3         1  ...        2.39
# 4         2  ...       16.98
#
# [5 rows x 5 columns]

# %%
dollarizer = lambda x: float(x[1:-1])
chipo.item_price = chipo.item_price.apply(dollarizer)

# %% [markdown]
# #### Step 13.c. 변경된 item_price의 데이터타입을 조회해주세요
#
# dtype('float64')

# %%
chipo.item_price.dtype
# Out:
# dtype('float64')

# %% [markdown]
# ### Step 14. 총 매출은 얼마인가요?
#
# 39237.02

# %%
(chipo['quantity']*chipo['item_price']).sum()
# Out:
# 39237.02

# %%
revenue = (chipo['quantity']* chipo['item_price']).sum()

print('Revenue was: $' + str(np.round(revenue,2)))
# Out:
# 39237.02

# %% [markdown]
# ### Step 15. 총 몇 건의 주문이 발생헀나요? (주문번호 기준)
#
# 1834
#
# **4가지 해답을 적어뒀습니다. 이 해답을 참조하여 Step 17을 해결해주세요**

# %%
chipo.order_id.nunique()
# Out:
# 1834

# %%
# Solution 1
len(chipo['order_id'].unique())
# Out:
# 1834

# %%
# Solution 2
chipo['order_id'].unique().shape
# Out:
# (1834,)

# %%
# Solution 3
chipo['order_id'].nunique()
# Out:
# 1834

# %%
# Solution 4
chipo['order_id'].value_counts().count()
# Out:
# 1834

# %% [markdown]
# ### Step 16. 주문당 평균 매출은 얼마인가요?
#
# 21.394231188658654

# %%
chipo['revenue'] = chipo['quantity'] * chipo['item_price']
chipo
# Out:
#       order_id  quantity  ... item_price revenue
# 0            1         1  ...       2.39    2.39
# 1            1         1  ...       3.39    3.39
# 2            1         1  ...       3.39    3.39
# 3            1         1  ...       2.39    2.39
# 4            2         2  ...      16.98   33.96
# ...        ...       ...  ...        ...     ...
# 4617      1833         1  ...      11.75   11.75
# 4618      1833         1  ...      11.75   11.75
# 4619      1834         1  ...      11.25   11.25
# 4620      1834         1  ...       8.75    8.75
# 4621      1834         1  ...       8.75    8.75
#
# [4622 rows x 6 columns]

# %%
chipo.groupby('order_id').sum()
# Out:
#           quantity  item_price  revenue
# order_id
# 1                4       11.56    11.56
# 2                2       16.98    33.96
# 3                2       12.67    12.67
# 4                2       21.00    21.00
# 5                2       13.70    13.70
# ...            ...         ...      ...
# 1830             2       23.00    23.00
# 1831             3       12.90    12.90
# 1832             2       13.20    13.20
# 1833             2       23.50    23.50
# 1834             3       28.75    28.75
#
# [1834 rows x 3 columns]

# %%
order = chipo.groupby(by=['order_id']).sum()
order
# Out:
#           quantity  item_price  revenue
# order_id
# 1                4       11.56    11.56
# 2                2       16.98    33.96
# 3                2       12.67    12.67
# 4                2       21.00    21.00
# 5                2       13.70    13.70
# ...            ...         ...      ...
# 1830             2       23.00    23.00
# 1831             3       12.90    12.90
# 1832             2       13.20    13.20
# 1833             2       23.50    23.50
# 1834             3       28.75    28.75
#
# [1834 rows x 3 columns]

# %%
order.mean().revenue
# Out:
# 21.394231188658654

# %%
# Solution 1

chipo['revenue'] = chipo['quantity'] * chipo['item_price']
order_grouped = chipo.groupby(by=['order_id']).sum()
order_grouped.mean()['revenue']
# Out:
# 21.394231188658654

# %%
# Solution 2

chipo.groupby(by=['order_id']).sum().mean()['revenue']

# %% [markdown]
# ### Step 17. 몇 종류의 item이 판매되었나요?
#
# 50

# %%
chipo.item_name.value_counts().count()
# Out:
# 50
